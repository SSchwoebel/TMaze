# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import os
import torch
import seaborn as sns
import copy

# %%
import sys
sys.path.append('../code/BalancingControl')
import tmaze_utils as tu
import inference_utils as iu
import inference as inf

import misc

# %%
groups = ["control", "cie"]

agents = ["BCC_2pars_planning_repetition_weight"]

# %%
results_dir = os.path.abspath('results')
inference_folder = os.path.join(results_dir, "inference")
print(inference_folder)
# Out:
# /home/sarah/src/TMaze/cie_task/results/inference

# %%
results = {}
data = {}
n_agents = {}
num_steps = 600

for grp in groups:
    base_dir = "processed_data"
    fname_data = os.path.join(base_dir, f"TMaze_{grp}_structured_data.json")
    structured_data = misc.load_file(fname_data, fname_data)
    data[grp] = structured_data
    n_agents[grp] = len(structured_data["subject"][0])
    for agt in agents:
        fname_base = agt+"_"+grp+"_inference_"
        fname_str = fname_base + str(num_steps)+'_'+str(n_agents[grp])+'agents'
        # define folder where we want to save data
        base_dir = os.path.join(inference_folder,fname_base[:-1])
        mean_df, sample_df, locs_df = iu.load_samples(base_dir, fname_str) 
        print(f"{agt}_{grp}")
        results[f"{agt}_{grp}"] = {}
        results[f"{agt}_{grp}"]["mean_df"] = mean_df
        results[f"{agt}_{grp}"]["sample_df"] = sample_df
        results[f"{agt}_{grp}"]["locs_df"] = locs_df
# Out:
# BCC_2pars_planning_repetition_weight_control
# BCC_2pars_planning_repetition_weight_cie

# %%
base_dir = "processed_data"
fname_plot_df = os.path.join(base_dir, "plot_df.csv")
plot_df = pd.read_csv(fname_plot_df)

# %%
plot_df["correct"][plot_df["trial_type"]=="early test"]
# Out:
# 75      0.0
# 76      0.0
# 77      0.0
# 78      1.0
# 79      0.0
#        ...
# 2315    0.0
# 2316    0.0
# 2317    0.0
# 2318    1.0
# 2319    0.0
# Name: correct, Length: 75, dtype: float64

# %%
plot_df[plot_df["trial_type"]=="early test"].groupby(["animal", "group"])["correct"].mean()
# Out:
# animal  group
# 20.0    control    0.4
# 24.0    cie        0.2
# 25.0    cie        0.2
# 26.0    cie        0.2
# 27.0    cie        0.4
# 32.0    cie        0.4
# 33.0    cie        0.0
# 34.0    cie        0.2
# 35.0    cie        0.2
# 38.0    control    0.6
# 39.0    control    0.4
# 44.0    control    0.2
# 45.0    control    0.2
# 46.0    control    1.0
# 47.0    control    0.6
# Name: correct, dtype: float64

# %%
plot_df[plot_df["trial_type"]=="late test"].groupby(["animal", "group"])["correct"].mean()
# Out:
# animal  group
# 20.0    control    0.4
# 24.0    cie        0.4
# 25.0    cie        0.4
# 26.0    cie        0.2
# 27.0    cie        0.8
# 32.0    cie        0.6
# 33.0    cie        0.2
# 34.0    cie        0.8
# 35.0    cie        0.6
# 38.0    control    0.8
# 39.0    control    0.4
# 44.0    control    0.6
# 45.0    control    1.0
# 46.0    control    0.2
# 47.0    control    0.8
# Name: correct, dtype: float64

# %%
print(results.keys())
results[agents[0]+"_cie"]
# Out:
# dict_keys(['BCC_2pars_planning_repetition_weight_control', 'BCC_2pars_planning_repetition_weight_cie'])
# {'mean_df':    Unnamed: 0  inferred dec temp  subject  inferred habitual tendency
#  0           0           0.690782        0                    1.716267
#  1           1           1.792931        1                    4.028704
#  2           2           0.852546        2                    2.203678
#  3           3           2.932296        3                    1.950544
#  4           4           0.888602        4                    2.383413
#  5           5           0.940980        5                    5.188447
#  6           6           1.577372        6                    2.287202
#  7           7           1.834022        7                    2.872371,
#  'sample_df':       Unnamed: 0  dec temp  habitual tendency  subject
#  0              0  1.007988           2.341030        0
#  1              1  2.924053           4.593257        1
#  2              2  0.822923           1.719426        2
#  3              3  2.183489           3.002844        3
#  4              4  0.793799           1.895835        4
#  ...          ...       ...                ...      ...
#  3995        3995  2.250279           2.856937        3
#  3996        3996  1.707886           1.403300        4
#  3997        3997  1.028393           5.071339        5
#  3998        3998  0.975382           2.638483        6
#  3999        3999  1.770344           4.711875        7
#
#  [4000 rows x 4 columns],
#  'locs_df':       Unnamed: 0     locs0     locs1  subject
#  0              0 -2.188380 -1.185286        0
#  1              1 -0.883731 -0.163058        1
#  2              2 -2.411602 -1.571922        2
#  3              3 -1.275314 -0.845944        3
#  4              4 -2.450802 -1.452719        4
#  ...          ...       ...       ...      ...
#  3995        3995 -1.236602 -0.916392        3
#  3996        3996 -1.580049 -1.812552        4
#  3997        3997 -2.166067  0.028538        5
#  3998        3998 -2.224882 -1.026062        6
#  3999        3999 -1.536571 -0.115378        7
#
#  [4000 rows x 4 columns]}

# %%
cie_early_test_accuracy = plot_df[plot_df["trial_type"]=="early test"][plot_df["group"]=="cie"].groupby(["animal"])["correct"].mean().values
cie_late_test_accuracy = plot_df[plot_df["trial_type"]=="late test"][plot_df["group"]=="cie"].groupby(["animal"])["correct"].mean().values
cie_early_training_accuracy = plot_df[plot_df["detailed_trial_type"]=="early training"][plot_df["group"]=="cie"].groupby(["animal"])["correct"].mean().values
cie_late_training_accuracy = plot_df[plot_df["detailed_trial_type"]=="late training"][plot_df["group"]=="cie"].groupby(["animal"])["correct"].mean().values
cie_early_test_first_choice = plot_df[plot_df["trial"]==75][plot_df["group"]=="cie"].groupby(["animal"])["correct"].mean().values
cie_late_test_first_choice = plot_df[plot_df["trial"]==155][plot_df["group"]=="cie"].groupby(["animal"])["correct"].mean().values

cie_dec_temp = results[agents[0]+"_cie"]["mean_df"]["inferred dec temp"]
cie_hab_tend = results[agents[0]+"_cie"]["mean_df"]["inferred habitual tendency"]
# Out:
# /tmp/ipykernel_4430/1125224830.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cie_early_test_accuracy = plot_df[plot_df["trial_type"]=="early test"][plot_df["group"]=="cie"].groupby(["animal"])["correct"].mean().values
# /tmp/ipykernel_4430/1125224830.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cie_late_test_accuracy = plot_df[plot_df["trial_type"]=="late test"][plot_df["group"]=="cie"].groupby(["animal"])["correct"].mean().values
# /tmp/ipykernel_4430/1125224830.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cie_early_training_accuracy = plot_df[plot_df["detailed_trial_type"]=="early training"][plot_df["group"]=="cie"].groupby(["animal"])["correct"].mean().values
# /tmp/ipykernel_4430/1125224830.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cie_late_training_accuracy = plot_df[plot_df["detailed_trial_type"]=="late training"][plot_df["group"]=="cie"].groupby(["animal"])["correct"].mean().values
# /tmp/ipykernel_4430/1125224830.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cie_early_test_first_choice = plot_df[plot_df["trial"]==75][plot_df["group"]=="cie"].groupby(["animal"])["correct"].mean().values
# /tmp/ipykernel_4430/1125224830.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cie_late_test_first_choice = plot_df[plot_df["trial"]==155][plot_df["group"]=="cie"].groupby(["animal"])["correct"].mean().values

# %%
cie_dict = {"early training acc": cie_early_training_accuracy, "early test acc": cie_early_test_accuracy, 
                "late training acc": cie_late_training_accuracy, "late test acc": cie_late_test_accuracy,
                "early test first": cie_early_test_first_choice, "late test first": cie_late_test_first_choice,
                "dec temp": cie_dec_temp, "hab tend": cie_hab_tend}

cie_df = pd.DataFrame(cie_dict)

# %%
cie_df.corr()
# Out:
#                     early training acc  early test acc  late training acc  \
# early training acc            1.000000       -0.461849          -0.635086
# early test acc               -0.461849        1.000000           0.694716
# late training acc            -0.635086        0.694716           1.000000
# late test acc                -0.502670        0.652753           0.348723
# early test first             -0.437329        0.551677           0.830589
# late test first              -0.330590       -0.208514           0.354441
# dec temp                     -0.525602        0.425788           0.119440
# hab tend                     -0.180806       -0.690363          -0.217231
#
#                     late test acc  early test first  late test first  \
# early training acc      -0.502670         -0.437329        -0.330590
# early test acc           0.652753          0.551677        -0.208514
# late training acc        0.348723          0.830589         0.354441
# late test acc            1.000000          0.169031         0.223607
# early test first         0.169031          1.000000         0.377964
# late test first          0.223607          0.377964         1.000000
# dec temp                 0.664315         -0.294584        -0.181991
# hab tend                -0.500094         -0.151328         0.318231
#
#                     dec temp  hab tend
# early training acc -0.525602 -0.180806
# early test acc      0.425788 -0.690363
# late training acc   0.119440 -0.217231
# late test acc       0.664315 -0.500094
# early test first   -0.294584 -0.151328
# late test first    -0.181991  0.318231
# dec temp            1.000000 -0.107543
# hab tend           -0.107543  1.000000

# %%
control_early_test_accuracy = plot_df[plot_df["detailed_trial_type"]=="early test"][plot_df["group"]=="control"].groupby(["animal"])["correct"].mean().values
control_late_test_accuracy = plot_df[plot_df["detailed_trial_type"]=="late test"][plot_df["group"]=="control"].groupby(["animal"])["correct"].mean().values
control_early_training_accuracy = plot_df[plot_df["detailed_trial_type"]=="early training"][plot_df["group"]=="control"].groupby(["animal"])["correct"].mean().values
control_late_training_accuracy = plot_df[plot_df["detailed_trial_type"]=="late training"][plot_df["group"]=="control"].groupby(["animal"])["correct"].mean().values
control_early_test_first_choice = plot_df[plot_df["trial"]==75][plot_df["group"]=="control"].groupby(["animal"])["correct"].mean().values
control_late_test_first_choice = plot_df[plot_df["trial"]==155][plot_df["group"]=="control"].groupby(["animal"])["correct"].mean().values

control_dec_temp = results[agents[0]+"_control"]["mean_df"]["inferred dec temp"]
control_hab_tend = results[agents[0]+"_control"]["mean_df"]["inferred habitual tendency"]
# Out:
# /tmp/ipykernel_4430/1103311736.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   control_early_test_accuracy = plot_df[plot_df["detailed_trial_type"]=="early test"][plot_df["group"]=="control"].groupby(["animal"])["correct"].mean().values
# /tmp/ipykernel_4430/1103311736.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   control_late_test_accuracy = plot_df[plot_df["detailed_trial_type"]=="late test"][plot_df["group"]=="control"].groupby(["animal"])["correct"].mean().values
# /tmp/ipykernel_4430/1103311736.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   control_early_training_accuracy = plot_df[plot_df["detailed_trial_type"]=="early training"][plot_df["group"]=="control"].groupby(["animal"])["correct"].mean().values
# /tmp/ipykernel_4430/1103311736.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   control_late_training_accuracy = plot_df[plot_df["detailed_trial_type"]=="late training"][plot_df["group"]=="control"].groupby(["animal"])["correct"].mean().values
# /tmp/ipykernel_4430/1103311736.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   control_early_test_first_choice = plot_df[plot_df["trial"]==75][plot_df["group"]=="control"].groupby(["animal"])["correct"].mean().values
# /tmp/ipykernel_4430/1103311736.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   control_late_test_first_choice = plot_df[plot_df["trial"]==155][plot_df["group"]=="control"].groupby(["animal"])["correct"].mean().values

# %%
control_dict = {"early training acc": control_early_training_accuracy, "early test acc": control_early_test_accuracy, 
                "late training acc": control_late_training_accuracy, "late test acc": control_late_test_accuracy,
                "early test first": control_early_test_first_choice, "late test first": control_late_test_first_choice,
                "dec temp": control_dec_temp, "hab tend": control_hab_tend}

control_df = pd.DataFrame(control_dict)

# %%
control_df.corr()
# Out:
#                     early training acc  early test acc  late training acc  \
# early training acc            1.000000        0.427954          -0.285548
# early test acc                0.427954        1.000000           0.668043
# late training acc            -0.285548        0.668043           1.000000
# late test acc                 0.335347       -0.506061          -0.942449
# early test first              0.464835        0.768273           0.342624
# late test first               0.380319       -0.523823          -0.742352
# dec temp                      0.439303       -0.165808          -0.359996
# hab tend                      0.089248        0.100565           0.363101
#
#                     late test acc  early test first  late test first  \
# early training acc       0.335347          0.464835         0.380319
# early test acc          -0.506061          0.768273        -0.523823
# late training acc       -0.942449          0.342624        -0.742352
# late test acc            1.000000         -0.241523         0.724569
# early test first        -0.241523          1.000000        -0.300000
# late test first          0.724569         -0.300000         1.000000
# dec temp                 0.195486         -0.006083         0.154260
# hab tend                -0.380291         -0.055701         0.157145
#
#                     dec temp  hab tend
# early training acc  0.439303  0.089248
# early test acc     -0.165808  0.100565
# late training acc  -0.359996  0.363101
# late test acc       0.195486 -0.380291
# early test first   -0.006083 -0.055701
# late test first     0.154260  0.157145
# dec temp            1.000000  0.295602
# hab tend            0.295602  1.000000

# %%
all_early_test_accuracy = np.append(control_early_test_accuracy, cie_early_test_accuracy)
all_late_test_accuracy = np.append(control_late_test_accuracy, cie_late_test_accuracy)
all_early_training_accuracy = np.append(control_early_training_accuracy, cie_early_training_accuracy)
all_late_training_accuracy = np.append(control_late_training_accuracy, cie_late_training_accuracy)
all_early_test_first_choice = np.append(control_early_test_first_choice, cie_early_test_first_choice)
all_late_test_first_choice = np.append(control_late_test_first_choice, cie_late_test_first_choice)

all_dec_temp = np.append(control_dec_temp, cie_dec_temp)
all_hab_tend = np.append(control_hab_tend, cie_hab_tend)

# %%
all_dict = {"early training acc": all_early_training_accuracy, "early test acc": all_early_test_accuracy, 
                "late training acc": all_late_training_accuracy, "late test acc": all_late_test_accuracy,
                "early test first": all_early_test_first_choice, "late test first": all_late_test_first_choice,
                "dec temp": all_dec_temp, "hab tend": all_hab_tend}

all_df = pd.DataFrame(all_dict)

# %%
all_df.corr()
# Out:
#                     early training acc  early test acc  late training acc  \
# early training acc            1.000000        0.237710          -0.237234
# early test acc                0.237710        1.000000           0.703625
# late training acc            -0.237234        0.703625           1.000000
# late test acc                -0.021148       -0.003043          -0.457948
# early test first              0.102321        0.677199           0.471870
# late test first               0.041773       -0.184310          -0.251914
# dec temp                     -0.320413       -0.169852          -0.225480
# hab tend                     -0.107095       -0.244791           0.099991
#
#                     late test acc  early test first  late test first  \
# early training acc      -0.021148          0.102321         0.041773
# early test acc          -0.003043          0.677199        -0.184310
# late training acc       -0.457948          0.471870        -0.251914
# late test acc            1.000000         -0.026958         0.484248
# early test first        -0.026958          1.000000         0.068041
# late test first          0.484248          0.068041         1.000000
# dec temp                 0.314530         -0.237767        -0.174539
# hab tend                -0.461711         -0.136325         0.184986
#
#                     dec temp  hab tend
# early training acc -0.320413 -0.107095
# early test acc     -0.169852 -0.244791
# late training acc  -0.225480  0.099991
# late test acc       0.314530 -0.461711
# early test first   -0.237767 -0.136325
# late test first    -0.174539  0.184986
# dec temp            1.000000  0.113402
# hab tend            0.113402  1.000000

# %%
from scipy.stats import ttest_ind

# %%
ttest_ind(control_dec_temp, cie_dec_temp)
# Out:
# TtestResult(statistic=np.float64(-1.8607036287621528), pvalue=np.float64(0.08555152675322678), df=np.float64(13.0))

# %%
ttest_ind(control_hab_tend, cie_hab_tend)
# Out:
# TtestResult(statistic=np.float64(-0.8014320734375577), pvalue=np.float64(0.43728565755548493), df=np.float64(13.0))

# %%
x_vars_of_interest = list(control_dict.keys())[:-2]
y_vars_of_interest = list(control_dict.keys())[-2:]

print(x_vars_of_interest)
print(y_vars_of_interest)

iu.plot_correlations(control_df, x_vars_of_interest=x_vars_of_interest, y_vars_of_interest=y_vars_of_interest)
# Out:
# ['early training acc', 'early test acc', 'late training acc', 'late test acc', 'early test first', 'late test first']
# ['dec temp', 'hab tend']

# %%
from scipy.stats import pearsonr

# %%
print("p val control dec temp & hab tend")
print(pearsonr(control_dec_temp, control_hab_tend))

print("p val control early test acc & dec temp")
print(pearsonr(control_early_test_accuracy, control_dec_temp))

print("p val control late test acc & dec temp")
print(pearsonr(control_late_test_accuracy, control_dec_temp))

print("p val control early test acc & hab tend")
print(pearsonr(control_early_test_accuracy, control_hab_tend))

print("p val control late test acc & hab tend")
print(pearsonr(control_late_test_accuracy, control_hab_tend))

print("p val control early test choice & dec temp")
print(pearsonr(control_early_test_first_choice, control_dec_temp))

print("p val control late test choice & dec temp")
print(pearsonr(control_late_test_first_choice, control_dec_temp))

print("p val control early test choice & hab tend")
print(pearsonr(control_early_test_first_choice, control_hab_tend))

print("p val control late test choice & hab tend")
print(pearsonr(control_late_test_first_choice, control_hab_tend))

print("p val control early training acc & dec temp")
print(pearsonr(control_early_training_accuracy, control_dec_temp))

print("p val control late training acc & dec temp")
print(pearsonr(control_late_training_accuracy, control_dec_temp))

print("p val control early training acc & hab tend")
print(pearsonr(control_early_training_accuracy, control_hab_tend))

print("p val control late training acc & hab tend")
print(pearsonr(control_late_training_accuracy, control_hab_tend))
# Out:
# p val control dec temp & hab tend
# PearsonRResult(statistic=np.float64(0.2956019284401817), pvalue=np.float64(0.5198051913791591))
# p val control early test acc & dec temp
# PearsonRResult(statistic=np.float64(-0.16580838309425555), pvalue=np.float64(0.722368289711225))
# p val control late test acc & dec temp
# PearsonRResult(statistic=np.float64(0.1954858578098037), pvalue=np.float64(0.6744374890107716))
# p val control early test acc & hab tend
# PearsonRResult(statistic=np.float64(0.10056451271627083), pvalue=np.float64(0.8301383525138472))
# p val control late test acc & hab tend
# PearsonRResult(statistic=np.float64(-0.38029119911389253), pvalue=np.float64(0.40005062540384306))
# p val control early test choice & dec temp
# PearsonRResult(statistic=np.float64(-0.006082914392223859), pvalue=np.float64(0.9896735148500978))
# p val control late test choice & dec temp
# PearsonRResult(statistic=np.float64(0.15426041118932882), pvalue=np.float64(0.7412241300702619))
# p val control early test choice & hab tend
# PearsonRResult(statistic=np.float64(-0.0557010903241234), pvalue=np.float64(0.9055855170461753))
# p val control late test choice & hab tend
# PearsonRResult(statistic=np.float64(0.1571454374402099), pvalue=np.float64(0.7365033864087398))
# p val control early training acc & dec temp
# PearsonRResult(statistic=np.float64(0.43930267664435585), pvalue=np.float64(0.32404582125174514))
# p val control late training acc & dec temp
# PearsonRResult(statistic=np.float64(-0.35999612302133843), pvalue=np.float64(0.4276709741638395))
# p val control early training acc & hab tend
# PearsonRResult(statistic=np.float64(0.089247956612281), pvalue=np.float64(0.8490906531783056))
# p val control late training acc & hab tend
# PearsonRResult(statistic=np.float64(0.36310139300980426), pvalue=np.float64(0.42339840490582376))

# %%
iu.plot_correlations(cie_df, x_vars_of_interest=x_vars_of_interest, y_vars_of_interest=y_vars_of_interest)

# %%
print("p val cie dec temp & hab tend")
print(pearsonr(cie_dec_temp, cie_hab_tend))

print("p val cie early test acc & dec temp")
print(pearsonr(cie_early_test_accuracy, cie_dec_temp))

print("p val cie late test acc & dec temp")
print(pearsonr(cie_late_test_accuracy, cie_dec_temp))

print("p val cie early test acc & hab tend")
print(pearsonr(cie_early_test_accuracy, cie_hab_tend))

print("p val cie late test acc & hab tend")
print(pearsonr(cie_late_test_accuracy, cie_hab_tend))

print("p val cie early test choice & dec temp")
print(pearsonr(cie_early_test_first_choice, cie_dec_temp))

print("p val cie late test choice & dec temp")
print(pearsonr(cie_late_test_first_choice, cie_dec_temp))

print("p val cie early test choice & hab tend")
print(pearsonr(cie_early_test_first_choice, cie_hab_tend))

print("p val cie late test choice & hab tend")
print(pearsonr(cie_late_test_first_choice, cie_hab_tend))

print("p val cie early training acc & dec temp")
print(pearsonr(cie_early_training_accuracy, cie_dec_temp))

print("p val cie late training acc & dec temp")
print(pearsonr(cie_late_training_accuracy, cie_dec_temp))

print("p val cie early training acc & hab tend")
print(pearsonr(cie_early_training_accuracy, cie_hab_tend))

print("p val cie late training acc & hab tend")
print(pearsonr(cie_late_training_accuracy, cie_hab_tend))
# Out:
# p val cie dec temp & hab tend
# PearsonRResult(statistic=np.float64(-0.10754313757609044), pvalue=np.float64(0.7999059638758228))
# p val cie early test acc & dec temp
# PearsonRResult(statistic=np.float64(0.42578776808305335), pvalue=np.float64(0.2928915051033274))
# p val cie late test acc & dec temp
# PearsonRResult(statistic=np.float64(0.6643149318032), pvalue=np.float64(0.07235629884570173))
# p val cie early test acc & hab tend
# PearsonRResult(statistic=np.float64(-0.6903632271606402), pvalue=np.float64(0.05804832436357105))
# p val cie late test acc & hab tend
# PearsonRResult(statistic=np.float64(-0.5000941736203334), pvalue=np.float64(0.2069319387316337))
# p val cie early test choice & dec temp
# PearsonRResult(statistic=np.float64(-0.29458407175124357), pvalue=np.float64(0.4787778775698057))
# p val cie late test choice & dec temp
# PearsonRResult(statistic=np.float64(-0.18199114798065377), pvalue=np.float64(0.6662263423877929))
# p val cie early test choice & hab tend
# PearsonRResult(statistic=np.float64(-0.15132765978731866), pvalue=np.float64(0.7205626443170976))
# p val cie late test choice & hab tend
# PearsonRResult(statistic=np.float64(0.3182310089758183), pvalue=np.float64(0.4423774200590649))
# p val cie early training acc & dec temp
# PearsonRResult(statistic=np.float64(-0.525601860880202), pvalue=np.float64(0.18095585846962345))
# p val cie late training acc & dec temp
# PearsonRResult(statistic=np.float64(0.11943951965451391), pvalue=np.float64(0.7781716605398709))
# p val cie early training acc & hab tend
# PearsonRResult(statistic=np.float64(-0.18080622526477208), pvalue=np.float64(0.6683042634302391))
# p val cie late training acc & hab tend
# PearsonRResult(statistic=np.float64(-0.21723088145774083), pvalue=np.float64(0.6053244010688409))

# %%
iu.plot_correlations(all_df, x_vars_of_interest=x_vars_of_interest, y_vars_of_interest=y_vars_of_interest)

# %%
print("p val all dec temp & hab tend")
print(pearsonr(all_dec_temp, all_hab_tend))

print("p val all early test acc & dec temp")
print(pearsonr(all_early_test_accuracy, all_dec_temp))

print("p val all late test acc & dec temp")
print(pearsonr(all_late_test_accuracy, all_dec_temp))

print("p val all early test acc & hab tend")
print(pearsonr(all_early_test_accuracy, all_hab_tend))

print("p val all late test acc & hab tend")
print(pearsonr(all_late_test_accuracy, all_hab_tend))

print("p val all early test choice & dec temp")
print(pearsonr(all_early_test_first_choice, all_dec_temp))

print("p val all late test choice & dec temp")
print(pearsonr(all_late_test_first_choice, all_dec_temp))

print("p val all early test choice & hab tend")
print(pearsonr(all_early_test_first_choice, all_hab_tend))

print("p val all late test choice & hab tend")
print(pearsonr(all_late_test_first_choice, all_hab_tend))

print("p val all early training acc & dec temp")
print(pearsonr(all_early_training_accuracy, all_dec_temp))

print("p val all late training acc & dec temp")
print(pearsonr(all_late_training_accuracy, all_dec_temp))

print("p val all early training acc & hab tend")
print(pearsonr(all_early_training_accuracy, all_hab_tend))

print("p val all late training acc & hab tend")
print(pearsonr(all_late_training_accuracy, all_hab_tend))
# Out:
# p val all dec temp & hab tend
# PearsonRResult(statistic=np.float64(0.11340157824690765), pvalue=np.float64(0.6873881105880305))
# p val all early test acc & dec temp
# PearsonRResult(statistic=np.float64(-0.16985156410543045), pvalue=np.float64(0.5450550061361328))
# p val all late test acc & dec temp
# PearsonRResult(statistic=np.float64(0.3145302902045206), pvalue=np.float64(0.253550649062785))
# p val all early test acc & hab tend
# PearsonRResult(statistic=np.float64(-0.2447909663225239), pvalue=np.float64(0.37923265053255245))
# p val all late test acc & hab tend
# PearsonRResult(statistic=np.float64(-0.4617114291965208), pvalue=np.float64(0.08317821086118239))
# p val all early test choice & dec temp
# PearsonRResult(statistic=np.float64(-0.23776680018440788), pvalue=np.float64(0.39348517224095203))
# p val all late test choice & dec temp
# PearsonRResult(statistic=np.float64(-0.17453921645938988), pvalue=np.float64(0.5338445469763846))
# p val all early test choice & hab tend
# PearsonRResult(statistic=np.float64(-0.1363249340364574), pvalue=np.float64(0.6280653622535114))
# p val all late test choice & hab tend
# PearsonRResult(statistic=np.float64(0.18498597649221926), pvalue=np.float64(0.5092367873218656))
# p val all early training acc & dec temp
# PearsonRResult(statistic=np.float64(-0.32041336454006436), pvalue=np.float64(0.2442948682815532))
# p val all late training acc & dec temp
# PearsonRResult(statistic=np.float64(-0.225479869630411), pvalue=np.float64(0.41908767186122475))
# p val all early training acc & hab tend
# PearsonRResult(statistic=np.float64(-0.10709481298200446), pvalue=np.float64(0.7040282470485353))
# p val all late training acc & hab tend
# PearsonRResult(statistic=np.float64(0.09999103163957454), pvalue=np.float64(0.7229212737002941))

# %%
control_omega = control_dec_temp / (control_dec_temp + control_hab_tend)

control_beta = (control_dec_temp + control_hab_tend)

control_dict["omega"] = control_omega
control_dict["beta"] = control_beta

full_control_df = pd.DataFrame(control_dict)

cie_omega = cie_dec_temp / (cie_dec_temp + cie_hab_tend)

cie_beta = (cie_dec_temp + cie_hab_tend)

cie_dict["omega"] = cie_omega
cie_dict["beta"] = cie_beta

full_cie_df = pd.DataFrame(cie_dict)

# %%
y_vars_of_interest = ["beta", "omega"]

print(x_vars_of_interest)
print(y_vars_of_interest)

iu.plot_correlations(full_control_df, x_vars_of_interest=x_vars_of_interest, y_vars_of_interest=y_vars_of_interest)
# Out:
# ['early training acc', 'early test acc', 'late training acc', 'late test acc', 'early test first', 'late test first']
# ['beta', 'omega']

# %%
print("p val control omega & beta")
print(pearsonr(control_omega, control_beta))

print("p val control early test acc & beta")
print(pearsonr(control_early_test_accuracy, control_beta))

print("p val control late test acc & beta")
print(pearsonr(control_late_test_accuracy, control_beta))

print("p val control early test acc & omega")
print(pearsonr(control_early_test_accuracy, control_omega))

print("p val control late test acc & omega")
print(pearsonr(control_late_test_accuracy, control_omega))

print("p val control early test choice & beta")
print(pearsonr(control_early_test_first_choice, control_beta))

print("p val control late test choice & beta")
print(pearsonr(control_late_test_first_choice, control_beta))

print("p val control early test choice & omega")
print(pearsonr(control_early_test_first_choice, control_omega))

print("p val control late test choice & omega")
print(pearsonr(control_late_test_first_choice, control_omega))

print("p val control early training acc & beta")
print(pearsonr(control_early_training_accuracy, control_beta))

print("p val control late training acc & beta")
print(pearsonr(control_late_training_accuracy, control_beta))

print("p val control early training acc & omega")
print(pearsonr(control_early_training_accuracy, control_omega))

print("p val control late training acc & omega")
print(pearsonr(control_late_training_accuracy, control_omega))
# Out:
# p val control omega & beta
# PearsonRResult(statistic=np.float64(-0.2708996482083414), pvalue=np.float64(0.5567940704880782))
# p val control early test acc & beta
# PearsonRResult(statistic=np.float64(0.047292903843345654), pvalue=np.float64(0.9198028283480768))
# p val control late test acc & beta
# PearsonRResult(statistic=np.float64(-0.28962838290494547), pvalue=np.float64(0.5286719851074122))
# p val control early test acc & omega
# PearsonRResult(statistic=np.float64(-0.28668366769381665), pvalue=np.float64(0.5330615513975797))
# p val control late test acc & omega
# PearsonRResult(statistic=np.float64(0.45587218067967933), pvalue=np.float64(0.30393142831190606))
# p val control early test choice & beta
# PearsonRResult(statistic=np.float64(-0.051334350674330204), pvalue=np.float64(0.9129668809724603))
# p val control late test choice & beta
# PearsonRResult(statistic=np.float64(0.18002355621129756), pvalue=np.float64(0.6993106498819768))
# p val control early test choice & omega
# PearsonRResult(statistic=np.float64(-0.06485766931649894), pvalue=np.float64(0.8901256356395879))
# p val control late test choice & omega
# PearsonRResult(statistic=np.float64(-0.0031843893206023877), pvalue=np.float64(0.9945940401974556))
# p val control early training acc & beta
# PearsonRResult(statistic=np.float64(0.19253195491688824), pvalue=np.float64(0.6791717403430537))
# p val control late training acc & beta
# PearsonRResult(statistic=np.float64(0.23203314344056064), pvalue=np.float64(0.6166060877270162))
# p val control early training acc & omega
# PearsonRResult(statistic=np.float64(0.2543368460175832), pvalue=np.float64(0.5820529761821188))
# p val control late training acc & omega
# PearsonRResult(statistic=np.float64(-0.6016273609083376), pvalue=np.float64(0.1529659896430356))

# %%
iu.plot_correlations(full_cie_df, x_vars_of_interest=x_vars_of_interest, y_vars_of_interest=y_vars_of_interest)

# %%
print("p val cie omega & beta")
print(pearsonr(cie_omega, cie_beta))

print("p val cie early test acc & beta")
print(pearsonr(cie_early_test_accuracy, cie_beta))

print("p val cie late test acc & beta")
print(pearsonr(cie_late_test_accuracy, cie_beta))

print("p val cie early test acc & omega")
print(pearsonr(cie_early_test_accuracy, cie_omega))

print("p val cie late test acc & omega")
print(pearsonr(cie_late_test_accuracy, cie_omega))

print("p val cie early test choice & beta")
print(pearsonr(cie_early_test_first_choice, cie_beta))

print("p val cie late test choice & beta")
print(pearsonr(cie_late_test_first_choice, cie_beta))

print("p val cie early test choice & omega")
print(pearsonr(cie_early_test_first_choice, cie_omega))

print("p val cie late test choice & omega")
print(pearsonr(cie_late_test_first_choice, cie_omega))

print("p val cie early training acc & beta")
print(pearsonr(cie_early_training_accuracy, cie_beta))

print("p val cie late training acc & beta")
print(pearsonr(cie_late_training_accuracy, cie_beta))

print("p val cie early training acc & omega")
print(pearsonr(cie_early_training_accuracy, cie_omega))

print("p val cie late training acc & omega")
print(pearsonr(cie_late_training_accuracy, cie_omega))
# Out:
# p val cie omega & beta
# PearsonRResult(statistic=np.float64(-0.0013185491464849652), pvalue=np.float64(0.9975277232158298))
# p val cie early test acc & beta
# PearsonRResult(statistic=np.float64(-0.3734813925301279), pvalue=np.float64(0.3621177079824886))
# p val cie late test acc & beta
# PearsonRResult(statistic=np.float64(-0.06988992287866799), pvalue=np.float64(0.8693824997919044))
# p val cie early test acc & omega
# PearsonRResult(statistic=np.float64(0.6441585568186458), pvalue=np.float64(0.08472124538074813))
# p val cie late test acc & omega
# PearsonRResult(statistic=np.float64(0.8127176921327872), pvalue=np.float64(0.014201874817052918))
# p val cie early test choice & beta
# PearsonRResult(statistic=np.float64(-0.3005895386399481), pvalue=np.float64(0.4694237367201449))
# p val cie late test choice & beta
# PearsonRResult(statistic=np.float64(0.18021263044072997), pvalue=np.float64(0.6693459047416521))
# p val cie early test choice & omega
# PearsonRResult(statistic=np.float64(-0.20081487105028184), pvalue=np.float64(0.633472381510819))
# p val cie late test choice & omega
# PearsonRResult(statistic=np.float64(-0.254629453339852), pvalue=np.float64(0.5428048721762834))
# p val cie early training acc & beta
# PearsonRResult(statistic=np.float64(-0.45704518161398605), pvalue=np.float64(0.25490195044843467))
# p val cie late training acc & beta
# PearsonRResult(statistic=np.float64(-0.12571827921583206), pvalue=np.float64(0.7667501850017472))
# p val cie early training acc & omega
# PearsonRResult(statistic=np.float64(-0.32376530709733775), pvalue=np.float64(0.4340289239859269))
# p val cie late training acc & omega
# PearsonRResult(statistic=np.float64(0.16979384281711685), pvalue=np.float64(0.6877025569429475))

# %%
ttest_ind(control_omega, cie_omega)
# Out:
# TtestResult(statistic=np.float64(-0.9003730738840181), pvalue=np.float64(0.38429794018512237), df=np.float64(13.0))

# %%
ttest_ind(control_beta, cie_beta)
# Out:
# TtestResult(statistic=np.float64(-1.5323241294953631), pvalue=np.float64(0.1494103522152375), df=np.float64(13.0))

# %%
group_comp_dict = {"group": ["control"]*n_agents["control"]+["cie"]*n_agents["cie"], "early acc": np.append(control_early_test_accuracy, cie_early_test_accuracy), 
                   "late acc": np.append(control_late_test_accuracy, cie_late_test_accuracy), "dec temp": np.append(control_dec_temp, cie_dec_temp), "hab tend": np.append(control_hab_tend,cie_hab_tend),
                   "omega": np.append(control_omega, cie_omega), "beta": np.append(control_beta, cie_beta)}

group_comp_df = pd.DataFrame(group_comp_dict)

# %%
plt.figure()
sns.violinplot(data=group_comp_df, y="hab tend", hue="group", inner="point")
plt.show()

# %%
plt.figure()
sns.violinplot(data=group_comp_df, y="dec temp", hue="group", inner="point")
plt.show()

# %%
plt.figure()
sns.violinplot(data=group_comp_df, y="omega", hue="group", inner="point")
plt.show()

# %%
plt.figure()
sns.violinplot(data=group_comp_df, y="beta", hue="group", inner="point")
plt.show()

# %%
plt.figure()
sns.relplot(data=group_comp_df, y="hab tend", x="early acc", hue="group")
plt.show()

plt.figure()
sns.relplot(data=group_comp_df, y="hab tend", x="late acc", hue="group")
plt.show()

# %%
plt.figure()
sns.relplot(data=group_comp_df, y="dec temp", x="early acc", hue="group", sizes=(5))
plt.show()

plt.figure()
sns.scatterplot(data=group_comp_df, y="dec temp", x="late acc", hue="group", marker="o", s=80)#sizes=(200,200))
plt.show()
